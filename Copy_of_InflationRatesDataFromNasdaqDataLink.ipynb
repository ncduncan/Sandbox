# %% [markdown]
# <a href="https://colab.research.google.com/github/ncduncan/Sandbox/blob/master/Copy_of_InflationRatesDataFromNasdaqDataLink.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-decouple
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Get API KEY from Nasdaq Data Link
#
# write to your .env file
#
#
# use decouple to retrieve your secret keys

# %%
#!echo NASDAQ_API= > .env

# %%
#from decouple import config

# %%
#NASDAQ_API = config('NASDAQ_API')

# %% [markdown]
# # Install Nasdaq-Data-Link

# %%
#!pip install nasdaq-data-link

# %%
import nasdaqdatalink

# %%
nasdaqdatalink.ApiConfig.api_key = 'HAKUFnxf3SaZ2Rqb1GRM'

# %%
# dir(nasdaqdatalink)

# %%
db = nasdaqdatalink.Database('RATEINF')

# %%
# db.data_fields()
# Out:
# ['id',
#  'name',
#  'database_code',
#  'description',
#  'datasets_count',
#  'downloads',
#  'premium',
#  'image',
#  'favorite',
#  'url_name',
#  'exclusive']

# %%
# dir(db)

# %%
# db.to_list()

# %%
# ds = db.datasets()

# %%
# dir(ds)

# %%
# pd.DataFrame(ds.to_list())
# Out:
#           0              1        2                                   3   \
# 0   11319885        CPI_USA  RATEINF          Consumer Price Index - USA
# 1   11319884        CPI_GBR  RATEINF           Consumer Price Index - UK
# 2   11319883        CPI_CHE  RATEINF  Consumer Price Index - Switzerland
# 3   11319881        CPI_JPN  RATEINF        Consumer Price Index - Japan
# 4   11319880        CPI_ITA  RATEINF        Consumer Price Index - Italy
# 5   11319879        CPI_FRA  RATEINF       Consumer Price Index - France
# 6   11319878        CPI_EUR  RATEINF    Consumer Price Index - Euro Area
# 7   11319877        CPI_DEU  RATEINF      Consumer Price Index - Germany
# 8   11319876        CPI_CAN  RATEINF       Consumer Price Index - Canada
# 9   11319870  INFLATION_USA  RATEINF                 Inflation YOY - USA
# 10  11319869  INFLATION_GBR  RATEINF                  Inflation YOY - UK
# 11  11319868  INFLATION_CHE  RATEINF         Inflation YOY - Switzerland
# ...

# %%
# import pandas as pd
# tables = [f"RATEINF/{region}" for region in pd.DataFrame(ds.to_list())[1].to_list()]

# %%
# tables.sort()

# %%
# tables
# Out:
# ['RATEINF/CPI_ARG',
#  'RATEINF/CPI_AUS',
#  'RATEINF/CPI_CAN',
#  'RATEINF/CPI_CHE',
#  'RATEINF/CPI_DEU',
#  'RATEINF/CPI_EUR',
#  'RATEINF/CPI_FRA',
#  'RATEINF/CPI_GBR',
#  'RATEINF/CPI_ITA',
#  'RATEINF/CPI_JPN',
#  'RATEINF/CPI_NZL',
#  'RATEINF/CPI_RUS',
#  'RATEINF/CPI_USA',
#  'RATEINF/INFLATION_ARG',
#  'RATEINF/INFLATION_AUS',
#  'RATEINF/INFLATION_CAN',
#  'RATEINF/INFLATION_CHE',
#  'RATEINF/INFLATION_DEU',
#  'RATEINF/INFLATION_EUR',
#  'RATEINF/INFLATION_FRA',
#  'RATEINF/INFLATION_GBR',
#  'RATEINF/INFLATION_ITA',
#  'RATEINF/INFLATION_JPN',
#  'RATEINF/INFLATION_NZL',
#  'RATEINF/INFLATION_RUS',
#  'RATEINF/INFLATION_USA']

# %%
# data_cpi = []
# data_inflation = []
# for region in tables:
#   df_tmp = nasdaqdatalink.get(region, paginate=True)
#   df_tmp.columns = [region.split('/')[-1]]
#   if 'CPI' in region:
#     data_cpi.append(df_tmp)
#   else:
#     data_inflation.append(df_tmp)

# %%
# pd.concat(data_cpi).sort_index().ffill().plot(figsize=(18, 9))

# %%
# pd.concat(data_inflation).sort_index().ffill().plot(figsize=(18, 40), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f830a92d820>,
# ...
#       dtype=object)
